# %%
# Show graph of losses over number of batches used for training

_ = Local(losses=[])

def load_losses(path):
    global losses

    with open(DRIVE_PATH + path, "r") as f:
        _.losses += [float(l.replace("\n", ""))  for l in f.readlines()]

load_losses("losses.txt")

plt.plot(_.losses)
plt.show()
